# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sb
from prettytable import PrettyTable

np.set_printoptions(precision=3, suppress=True)

def print_table(th, td):
    table = PrettyTable(th)
    columns = len(th) 
    td_data = td.tolist()[:]
    while td_data:
        table.add_row(td_data[:columns])
        td_data = td_data[columns:]
    print(table)

# %%
df = pd.read_csv('csv/Task1-Var13.csv')
x = df.to_numpy()
print("Выборка (вариант 13) \n", x)
# Out:
# Выборка (вариант 13)
#  [[ 2.064  0.94   4.928  0.943  3.695  5.482  0.705  0.939  1.396  2.415]
#  [ 1.395  0.146  1.64   1.997  0.041  1.548  2.209  1.059  0.232  0.039]
#  [ 0.466  1.32   0.241  2.868  4.77   2.482  1.023  1.389  0.222  2.169]
#  [ 5.375  1.608  1.941  1.464  1.208  1.542  0.619  1.906  0.741  2.604]
#  [ 6.927  1.79   4.381  0.043  1.503  0.417  2.303  1.537 10.921  2.087]
#  [ 9.411  3.633  2.254  2.814  0.497  3.044  2.832  1.367  3.648  9.483]
#  [ 1.668  0.828  5.557  6.035  1.171  0.333  1.104  2.632  0.58   2.676]
#  [ 3.604  0.823  1.396  7.921  3.041  2.261  0.233  2.1    0.026  0.36 ]
#  [ 2.939  3.2    0.234  5.611  6.665  3.222  3.233  2.51   1.78   0.028]
#  [ 4.649  0.577  0.472  0.13   4.305  1.198  5.612  2.77   0.132  0.18 ]
#  [ 5.663  1.774  1.097  0.305  1.638  6.714  0.088  3.123  0.149  5.202]
#  [ 0.401  9.007  0.148  1.748  6.172  2.424  1.253  0.33   2.136  2.776]
#  [ 0.231  1.896  2.424  0.659  0.116  9.778  0.43   4.015  1.162  0.651]
#  [ 0.23   0.514  7.561  5.953  0.255  1.739  0.196  0.301  0.071  1.896]
#  [ 2.29   1.102  3.983  0.152  1.307  0.503  1.423  0.006  0.15   3.704]]

# %%
# Задание 1 (Найдите крайние члены вариационного ряда и размах выборки)

n = x.size
Max = np.amax(x)
Min = np.amin(x)
w = Max - Min

print("Размер n = %d\nКрайние члены вариационного ряда max = %.3f, min = %.5f\nРазмах выборки w = %f" 
      %(n, Max, Min, w))
# Out:
# Размер n = 150
# Крайние члены вариационного ряда max = 10.921, min = 0.00621
# Размах выборки w = 10.914790

# %%
# Задание 2 (Осуществите группировку данных)
l = math.trunc(1 + math.log2(n))
h = w / l

print("Число интервалов l = %d\nШаг(ширина интервалов группировки) h = %f" %(l, h))

hist, bin_edges = np.histogram(x, l)
bin_edges_average = np.zeros(bin_edges[:8].size)
for i in range (l):
    bin_edges_average[i] = (bin_edges[i] + bin_edges[i + 1]) / 2 
f1 = bin_edges_average
f2 = hist

print("\n")
print("Cредние значения каждого из  интервалов (первый столбец)\nЧастоты попадания элементов в каждый из интервалов(второй столбец)")
print(f1, f2)

p = hist / n
print("\n")
print("Относительные частоты ")
print(p)

Int = f1
intl = Int - h / 2
intl = np.append(intl, Max)
print("Границы интервалов")
print(intl)
# Out:
# Число интервалов l = 8
# Шаг(ширина интервалов группировки) h = 1.364349
#
#
# Cредние значения каждого из  интервалов (первый столбец)
# Частоты попадания элементов в каждый из интервалов(второй столбец)
# [ 0.688  2.053  3.417  4.781  6.146  7.51   8.874 10.239] [64 42 19  7 10  3  3  2]
#
#
# Относительные частоты
# [0.427 0.28  0.127 0.047 0.067 0.02  0.02  0.013]
# Границы интервалов
# [ 0.006  1.371  2.735  4.099  5.464  6.828  8.192  9.557 10.921]

# %%
# Задание 3 (По сгруппированным данным постройте гистограмму относительных частот)

sb.set_style("whitegrid")
plt.figure(figsize=(10,6))
X = Int
Y = p / h
plt.bar(X, Y, width=h, color='navy')
plt.plot(X, Y, color='red')
plt.xlabel("int")
plt.ylabel("p / h")
plt.show()

# %%
xm = sum(x[i, j] for i in range(np.shape(x)[0]) for j in range(np.shape(x)[1])) / n
s2 = sum((x[i, j] - xm) ** 2 for i in range(np.shape(x)[0]) for j in range(np.shape(x)[1])) / (n - 1)
print(xm, s2)
print(1 / xm)
# Out:
# 2.275368066666667 5.256677917739189
# 0.43948933565942333

# %% [markdown]
# $M\xi =  \displaystyle\int\limits_{-\infty}^{+\infty} xp_\xi(x)dx = \int\limits_0^{+\infty} x \lambda e^{-\lambda x} dx = \dfrac{1}{\lambda}$
#
# $M\xi = xm \rightarrow \lambda = \dfrac{1}{xm} = 0,439$

# %%
from scipy.stats import expon

sb.set_style("whitegrid")
ls = np.linspace(0,10)
pdf = expon.pdf(ls, scale=xm)
plt.plot(ls, pdf, color='red')
plt.xlabel('intervals')
plt.ylabel('Probability Density')
X = Int
Y = p / h
plt.bar(X, Y, width=h, color='navy')
plt.show()

# %%
def ind(x):
    if (x > 0).any():
        return 1
    return 0

kum = np.empty(len(p) + 1)
kum[0] = 0
l = len(Int) - 1
for k in range(1, l + 2):
    kum[k] = sum(p[i] for i in range(0, k))

    
def femp(x):
    return sum(p[i] * ind(x - Int[i]) for i in range(l))

print(Int[0])
# Out:
# 0.688384375

# %%
sb.set_style("whitegrid")
ls = np.arange(0, 10, 1)
cdf = expon.cdf(ls, scale=xm)
plt.plot(ls, cdf, color='red')
plt.plot(ls, np.ones(len(ls)), color='black')
plt.step(Int, kum, color='navy')
plt.xlabel('')
plt.ylabel('')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [187], line 6
#       4 plt.plot(ls, cdf, color='red')
#       5 plt.plot(ls, np.ones(len(ls)), color='black')
# ----> 6 plt.step(Int, kum, color='navy')
#       7 plt.xlabel('')
#       8 plt.ylabel('')
#
# File ~/Desktop/math_stat/jup_notebook/lib/python3.10/site-packages/matplotlib/pyplot.py:2858, in step(x, y, where, data, *args, **kwargs)
#    2856 @_copy_docstring_and_deprecators(Axes.step)
#    2857 def step(x, y, *args, where='pre', data=None, **kwargs):
# -> 2858     return gca().step(
#    2859         x, y, *args, where=where,
#    2860         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/Desktop/math_stat/jup_notebook/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2150, in Axes.step(self, x, y, where, data, *args, **kwargs)
#    2148 _api.check_in_list(('pre', 'post', 'mid'), where=where)
#    2149 kwargs['drawstyle'] = 'steps-' + where
# -> 2150 return self.plot(x, y, *args, data=data, **kwargs)
#
# File ~/Desktop/math_stat/jup_notebook/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/Desktop/math_stat/jup_notebook/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/Desktop/math_stat/jup_notebook/lib/python3.10/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (14,) and (9,)
